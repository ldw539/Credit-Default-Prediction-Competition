# %%
import numpy as np
import pandas as pd
import gc
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score

# %%
bankdata  = pd.read_csv("cleanbankdata.csv")
testdata = pd.read_csv("cleantestdata.csv")
data = pd.concat([bankdata,testdata]).reset_index(drop=True)

# %%
data
# Out:
#        Unnamed: 0  loan_id  user_id    total_loan  year_of_loan  interest  \
# 0               0  1040418   240418  31818.181820             3    11.466
# 1               1  1025197   225197  28000.000000             5    16.841
# 2               2  1009360   209360  17272.727270             3     8.900
# 3               3  1039708   239708  20000.000000             3     4.788
# 4               4  1027483   227483  15272.727270             3    12.790
# ...           ...      ...      ...           ...           ...       ...
# 14993        4995  1008856   208856   9454.545455             5    12.015
# 14994        4996  1016651   216651   5500.000000             3     7.970
# 14995        4997  1024140   224140  30545.454550             3     8.900
# 14996        4998  1014316   214316   4090.909091             3     6.030
# 14997        4999  1012946   212946  14727.272730             3     7.970
#
#        monthly_payment  class  employer_type  industry  ...    f3    f4  \
# 0              1174.91      3              3        13  ...   5.0   4.0
# 1               670.69      3              3        13  ...  45.0  22.0
# 2               603.32      1              3         3  ...  28.0  19.0
# 3               602.30      1              1        10  ...  15.0   9.0
# 4               470.31      3              3         2  ...  15.0   4.0
# ...                ...    ...            ...       ...  ...   ...   ...
# 14993           183.47      3              3         2  ...  14.0   8.0
# 14994           172.28      1              3         8  ...   5.0   3.0
# 14995           889.09      1              0         8  ...  20.0  14.0
# 14996           152.18      1              3        10  ...  10.0  10.0
# 14997           563.81      1              4         0  ...   8.0   7.0
#
#        early_return  early_return_amount  early_return_amount_3mon  isDefault  \
# 0                 3                 9927                  0.000000        0.0
# 1                 0                    0                  0.000000        0.0
# 2                 0                    0                  0.000000        0.0
# 3                 0                    0                  0.000000        0.0
# 4                 0                    0                  0.000000        0.0
# ...             ...                  ...                       ...        ...
# 14993             0                    0                  0.000000        NaN
# 14994             3                 1564                  0.000000        NaN
# 14995             2                 5456               1510.892308        NaN
# 14996             3                  223                 41.169231        NaN
# 14997             3                 1561                360.230769        NaN
#
#        issue_date_month  issue_date_dayofweek  earliesCreditMon  \
# 0                    10                     5                12
# 1                     6                     5                 4
# 2                     1                     2                10
# 3                     7                     2                 6
# 4                     7                     4                 5
# ...                 ...                   ...               ...
# 14993                 1                     5                 7
# 14994                 5                     0                 4
# 14995                12                     6                10
# 14996                 9                     5                 3
# 14997                 6                     3                 7
#
#        earliesCreditYear
# 0                   2001
# 1                   1990
# 2                   1991
# 3                   2001
# 4                   2001
# ...                  ...
# 14993               2001
# 14994               2001
# 14995               1986
# 14996               1999
# 14997               2001
#
# [14998 rows x 39 columns]

# %%
train = data[data["isDefault"].notna()]
test = data[data["isDefault"].isna()]
y = train["isDefault"]

# %%
features = [f for f in train.columns if f not in ['loan_id', 'user_id', 'isDefault']]

# %%
ordata_preds = np.zeros(train.shape[0])
preds = np.zeros(test.shape[0])

# %%
kfold = StratifiedKFold(n_splits = 10,shuffle=True ,random_state=0)

# %%
for k, (train_index, valuation_index) in enumerate(kfold.split(train,y)):
    train_x, train_y = train[features].iloc[train_index], y.iloc[train_index]
    valuation_x, valuation_y = train[features].iloc[valuation_index], y.iloc[valuation_index]
    svm = SVC(random_state=0,gamma=0.10, C=10.0)    
    svm.fit(train_x,train_y)
    ordata_preds[valuation_index]  = svm.predict(valuation_x)
    print("Fold %2d AUC : %.6f" % (k + 1, roc_auc_score(valuation_y, ordata_preds[valuation_index])))
    preds  += svm.predict(test[features]) / kfold.n_splits
    del svm, train_x, train_y, valuation_x, valuation_y 
    gc.collect()
print(" Full AUC score %.6f" % roc_auc_score(y, ordata_preds))
# Out:
# Fold  1 AUC : 0.500000
# Fold  2 AUC : 0.500000
# Fold  3 AUC : 0.500000
# Fold  4 AUC : 0.500000
# Fold  5 AUC : 0.500000
# Fold  6 AUC : 0.500000
# Fold  7 AUC : 0.500000
# Fold  8 AUC : 0.500000
# Fold  9 AUC : 0.500000
# Fold 10 AUC : 0.500000
#  Full AUC score 0.500000

# %%
test["isDefault"] = preds
# Out:
# <ipython-input-12-4cacd7473762>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["isDefault"] = preds

# %%
results = test[["loan_id","isDefault"]]
results = results.rename(columns={"loan_id":"id"})
results
# Out:
#             id  isDefault
# 9998   1000575        0.0
# 9999   1028125        0.0
# 10000  1010694        0.0
# 10001  1026712        0.0
# 10002  1002895        0.0
# ...        ...        ...
# 14993  1008856        0.0
# 14994  1016651        0.0
# 14995  1024140        0.0
# 14996  1014316        0.0
# 14997  1012946        0.0
#
# [5000 rows x 2 columns]

# %%
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
results.to_csv("svmmodel.csv",index=False)
